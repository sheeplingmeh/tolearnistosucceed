# %% [markdown]
# # Motivation
# Just to practice data skills and possibly identify a cash cow opportunity
#
# # Business understanding
# There is only 1 licensed operator for lottery in Singapore by Singapore Pools. As a governement organisation it has full control over the lottery scene and wages placed on any other platforms/organisations are illegal. In Singapore Pools there are a number of number based lottery games, namely: 4D (4 digits), TOTO (6 matching numbers from 1-49), Singapore Sweep. The draws take place weekly and prize money defers based on the probability. With TOTO, since the odds of winning is drastically lower compared to 4D, it typically offers a 1mil SGD payout.
#
# Probability vs winnings 4D and TOTO
# | Type | Probability | Winnings (SGD)|
# |-------|------------|-------------|
# | 4D | 1/10000 | 2,000 - 3,000 |
# | TOTO | 1/C(49,6) = 7.5 e-8 or 1 in 13,983,816 of group 1| 1mil|

# %% [markdown]
# Objective:
# Determine if there are any patterns on 4d numbers. Are there numbers where it appears more frequently? The assumption made here is that not all balls used by Singapore pools are made equal and therefore there is a possibility that some numbers appear more frequently than others.
#
# Step 1: Determine the layout of the singapore pools website. Read source and identify the HTML tags to pull
# Step 2:

# %% [markdown]
# # Extract data for analysis
# Since there is no existing consolidated dataset for the winning numbers, the information can be downloaded from the official Singapore pools webpage.

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
import numpy as np

# %%
def fetch_4d_date_list(date_url):
    response = requests.get(date_url)
    response.raise_for_status()
    soup = BeautifulSoup(response.text, 'html.parser') 

    list_sppl = soup.find('select', class_='form-control selectDrawList').find_all('option')
    #initiate list to store date,sppl
    date_list = []
    for option in list_sppl:
        sppl = option.get('querystring')
        #sppl=RHJhd051bWJlcj01MTU3
        sppl_date_string = option.get_text()
        sppl_date_formatted = datetime.strptime(sppl_date_string, '%a, %d %b %Y').strftime('%Y%m%d')
        date_list.append((sppl_date_formatted,sppl))

    return date_list

# %%
def fetch_4d_results(draw_date,url):
    # Send a GET request to the webpage
    response = requests.get(url)
    response.raise_for_status()  # Raise an exception for HTTP errors

    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    #data structure
    data = {
        'DrawDate': draw_date,
        'PrizeType': [],
        'PrizeNumber': []
    }

    prizes = {
        'First_Prize': soup.find('td', class_='tdFirstPrize').get_text().strip(),
        'Second_Prize': soup.find('td', class_='tdSecondPrize').get_text().strip(),
        'Third_Prize': soup.find('td', class_='tdThirdPrize').get_text().strip()
    }

    for prize_type, prize_number in prizes.items():
        data['PrizeType'].append(prize_type)
        data['PrizeNumber'].append(prize_number)
    
        # Extract Starter Prizes
    starter_prizes = soup.find('tbody', class_='tbodyStarterPrizes').find_all('td')
    for prize in starter_prizes:
        data['PrizeType'].append('Starter_Prize')
        data['PrizeNumber'].append(prize.get_text().strip())

    # Extract Consolation Prizes
    consolation_prizes = soup.find('tbody', class_='tbodyConsolationPrizes').find_all('td')
    for prize in consolation_prizes:
        data['PrizeType'].append('Consolation_Prize')
        data['PrizeNumber'].append(prize.get_text().strip())
    
    #convert to dataframe
    df = pd.DataFrame(data)

    return df

# %%
#get date list and the corresponding URL tag to append
date_url = 'https://www.singaporepools.com.sg/DataFileArchive/Lottery/Output/fourd_result_draw_list_en.html?v=2024y4m16d12h30m'

# URL of the page to scrape
#'https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTU3'
url_pre = 'https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?'

date_list_full = fetch_4d_date_list(date_url)
print(date_list_full)

#initialise dataframe
full_data = pd.DataFrame()


for i in range(0,len(date_list_full)):
    draw_date = date_list_full[i][0]
    url_sppl_append = date_list_full[i][1]
    url_full = url_pre + url_sppl_append 
    print(f'Draw date is {draw_date}, step number {i}\n{url_full}')
    draw_data = fetch_4d_results(draw_date,url_full)
    #print(draw_data)
    full_data = pd.concat([full_data, draw_data], ignore_index=True)

print('final dataframe is...')
print(full_data)
# Out:
# [('20240414', 'sppl=RHJhd051bWJlcj01MTU3'), ('20240413', 'sppl=RHJhd051bWJlcj01MTU2'), ('20240410', 'sppl=RHJhd051bWJlcj01MTU1'), ('20240407', 'sppl=RHJhd051bWJlcj01MTU0'), ('20240406', 'sppl=RHJhd051bWJlcj01MTUz'), ('20240403', 'sppl=RHJhd051bWJlcj01MTUy'), ('20240331', 'sppl=RHJhd051bWJlcj01MTUx'), ('20240330', 'sppl=RHJhd051bWJlcj01MTUw'), ('20240327', 'sppl=RHJhd051bWJlcj01MTQ5'), ('20240324', 'sppl=RHJhd051bWJlcj01MTQ4'), ('20240323', 'sppl=RHJhd051bWJlcj01MTQ3'), ('20240320', 'sppl=RHJhd051bWJlcj01MTQ2'), ('20240317', 'sppl=RHJhd051bWJlcj01MTQ1'), ('20240316', 'sppl=RHJhd051bWJlcj01MTQ0'), ('20240313', 'sppl=RHJhd051bWJlcj01MTQz'), ('20240310', 'sppl=RHJhd051bWJlcj01MTQy'), ('20240309', 'sppl=RHJhd051bWJlcj01MTQx'), ('20240306', 'sppl=RHJhd051bWJlcj01MTQw'), ('20240303', 'sppl=RHJhd051bWJlcj01MTM5'), ('20240302', 'sppl=RHJhd051bWJlcj01MTM4'), ('20240228', 'sppl=RHJhd051bWJlcj01MTM3'), ('20240225', 'sppl=RHJhd051bWJlcj01MTM2'), ('20240224', 'sppl=RHJhd051bWJlcj01MTM1'), ('20240221', 'sppl=RHJhd051bWJlcj01MTM0'), ('20240218', 'sppl=RHJhd051bWJlcj01MTMz'), ('20240217', 'sppl=RHJhd051bWJlcj01MTMy'), ('20240214', 'sppl=RHJhd051bWJlcj01MTMx'), ('20240211', 'sppl=RHJhd051bWJlcj01MTMw'), ('20240210', 'sppl=RHJhd051bWJlcj01MTI5'), ('20240207', 'sppl=RHJhd051bWJlcj01MTI4'), ('20240204', 'sppl=RHJhd051bWJlcj01MTI3'), ('20240203', 'sppl=RHJhd051bWJlcj01MTI2'), ('20240131', 'sppl=RHJhd051bWJlcj01MTI1'), ('20240128', 'sppl=RHJhd051bWJlcj01MTI0'), ('20240127', 'sppl=RHJhd051bWJlcj01MTIz'), ('20240124', 'sppl=RHJhd051bWJlcj01MTIy'), ('20240121', 'sppl=RHJhd051bWJlcj01MTIx'), ('20240120', 'sppl=RHJhd051bWJlcj01MTIw'), ('20240117', 'sppl=RHJhd051bWJlcj01MTE5'), ('20240114', 'sppl=RHJhd051bWJlcj01MTE4'), ('20240113', 'sppl=RHJhd051bWJlcj01MTE3'), ('20240110', 'sppl=RHJhd051bWJlcj01MTE2'), ('20240107', 'sppl=RHJhd051bWJlcj01MTE1'), ('20240106', 'sppl=RHJhd051bWJlcj01MTE0'), ('20240103', 'sppl=RHJhd051bWJlcj01MTEz'), ('20231231', 'sppl=RHJhd051bWJlcj01MTEy'), ('20231230', 'sppl=RHJhd051bWJlcj01MTEx'), ('20231227', 'sppl=RHJhd051bWJlcj01MTEw'), ('20231224', 'sppl=RHJhd051bWJlcj01MTA5'), ('20231223', 'sppl=RHJhd051bWJlcj01MTA4'), ('20231220', 'sppl=RHJhd051bWJlcj01MTA3'), ('20231217', 'sppl=RHJhd051bWJlcj01MTA2'), ('20231216', 'sppl=RHJhd051bWJlcj01MTA1'), ('20231213', 'sppl=RHJhd051bWJlcj01MTA0'), ('20231210', 'sppl=RHJhd051bWJlcj01MTAz'), ('20231209', 'sppl=RHJhd051bWJlcj01MTAy'), ('20231206', 'sppl=RHJhd051bWJlcj01MTAx'), ('20231203', 'sppl=RHJhd051bWJlcj01MTAw'), ('20231202', 'sppl=RHJhd051bWJlcj01MDk5'), ('20231129', 'sppl=RHJhd051bWJlcj01MDk4'), ('20231126', 'sppl=RHJhd051bWJlcj01MDk3'), ('20231125', 'sppl=RHJhd051bWJlcj01MDk2'), ('20231122', 'sppl=RHJhd051bWJlcj01MDk1'), ('20231119', 'sppl=RHJhd051bWJlcj01MDk0'), ('20231118', 'sppl=RHJhd051bWJlcj01MDkz'), ('20231115', 'sppl=RHJhd051bWJlcj01MDky'), ('20231112', 'sppl=RHJhd051bWJlcj01MDkx'), ('20231111', 'sppl=RHJhd051bWJlcj01MDkw'), ('20231108', 'sppl=RHJhd051bWJlcj01MDg5'), ('20231105', 'sppl=RHJhd051bWJlcj01MDg4'), ('20231104', 'sppl=RHJhd051bWJlcj01MDg3'), ('20231101', 'sppl=RHJhd051bWJlcj01MDg2'), ('20231029', 'sppl=RHJhd051bWJlcj01MDg1'), ('20231028', 'sppl=RHJhd051bWJlcj01MDg0'), ('20231025', 'sppl=RHJhd051bWJlcj01MDgz'), ('20231022', 'sppl=RHJhd051bWJlcj01MDgy'), ('20231021', 'sppl=RHJhd051bWJlcj01MDgx'), ('20231018', 'sppl=RHJhd051bWJlcj01MDgw'), ('20231015', 'sppl=RHJhd051bWJlcj01MDc5'), ('20231014', 'sppl=RHJhd051bWJlcj01MDc4'), ('20231011', 'sppl=RHJhd051bWJlcj01MDc3'), ('20231008', 'sppl=RHJhd051bWJlcj01MDc2'), ('20231007', 'sppl=RHJhd051bWJlcj01MDc1'), ('20231004', 'sppl=RHJhd051bWJlcj01MDc0'), ('20231001', 'sppl=RHJhd051bWJlcj01MDcz'), ('20230930', 'sppl=RHJhd051bWJlcj01MDcy'), ('20230927', 'sppl=RHJhd051bWJlcj01MDcx'), ('20230924', 'sppl=RHJhd051bWJlcj01MDcw'), ('20230923', 'sppl=RHJhd051bWJlcj01MDY5'), ('20230920', 'sppl=RHJhd051bWJlcj01MDY4'), ('20230917', 'sppl=RHJhd051bWJlcj01MDY3'), ('20230916', 'sppl=RHJhd051bWJlcj01MDY2'), ('20230913', 'sppl=RHJhd051bWJlcj01MDY1'),  ...
# Draw date is 20240414, step number 0
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTU3
# Draw date is 20240413, step number 1
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTU2
# Draw date is 20240410, step number 2
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTU1
# Draw date is 20240407, step number 3
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTU0
# Draw date is 20240406, step number 4
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTUz
# Draw date is 20240403, step number 5
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTUy
# Draw date is 20240331, step number 6
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTUx
# Draw date is 20240330, step number 7
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTUw
# Draw date is 20240327, step number 8
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTQ5
# Draw date is 20240324, step number 9
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTQ4
# Draw date is 20240323, step number 10
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTQ3
# Draw date is 20240320, step number 11
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTQ2
# Draw date is 20240317, step number 12
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTQ1
# Draw date is 20240316, step number 13
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTQ0
# Draw date is 20240313, step number 14
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTQz
# Draw date is 20240310, step number 15
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTQy
# Draw date is 20240309, step number 16
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTQx
# Draw date is 20240306, step number 17
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTQw
# Draw date is 20240303, step number 18
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTM5
# Draw date is 20240302, step number 19
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTM4
# Draw date is 20240228, step number 20
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTM3
# Draw date is 20240225, step number 21
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTM2
# Draw date is 20240224, step number 22
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTM1
# Draw date is 20240221, step number 23
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTM0
# Draw date is 20240218, step number 24
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTMz
# Draw date is 20240217, step number 25
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTMy
# Draw date is 20240214, step number 26
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTMx
# Draw date is 20240211, step number 27
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTMw
# Draw date is 20240210, step number 28
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTI5
# Draw date is 20240207, step number 29
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTI4
# Draw date is 20240204, step number 30
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTI3
# Draw date is 20240203, step number 31
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTI2
# Draw date is 20240131, step number 32
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTI1
# Draw date is 20240128, step number 33
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTI0
# Draw date is 20240127, step number 34
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTIz
# Draw date is 20240124, step number 35
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTIy
# Draw date is 20240121, step number 36
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTIx
# Draw date is 20240120, step number 37
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTIw
# Draw date is 20240117, step number 38
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTE5
# Draw date is 20240114, step number 39
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTE4
# Draw date is 20240113, step number 40
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTE3
# Draw date is 20240110, step number 41
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTE2
# Draw date is 20240107, step number 42
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTE1
# Draw date is 20240106, step number 43
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTE0
# Draw date is 20240103, step number 44
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTEz
# Draw date is 20231231, step number 45
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTEy
# Draw date is 20231230, step number 46
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTEx
# Draw date is 20231227, step number 47
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTEw
# Draw date is 20231224, step number 48
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTA5
# Draw date is 20231223, step number 49
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTA4
# Draw date is 20231220, step number 50
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTA3
# Draw date is 20231217, step number 51
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTA2
# Draw date is 20231216, step number 52
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTA1
# Draw date is 20231213, step number 53
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTA0
# Draw date is 20231210, step number 54
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTAz
# Draw date is 20231209, step number 55
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTAy
# Draw date is 20231206, step number 56
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTAx
# Draw date is 20231203, step number 57
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MTAw
# Draw date is 20231202, step number 58
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDk5
# Draw date is 20231129, step number 59
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDk4
# Draw date is 20231126, step number 60
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDk3
# Draw date is 20231125, step number 61
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDk2
# Draw date is 20231122, step number 62
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDk1
# Draw date is 20231119, step number 63
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDk0
# Draw date is 20231118, step number 64
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDkz
# Draw date is 20231115, step number 65
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDky
# Draw date is 20231112, step number 66
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDkx
# Draw date is 20231111, step number 67
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDkw
# Draw date is 20231108, step number 68
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDg5
# Draw date is 20231105, step number 69
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDg4
# Draw date is 20231104, step number 70
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDg3
# Draw date is 20231101, step number 71
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDg2
# Draw date is 20231029, step number 72
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDg1
# Draw date is 20231028, step number 73
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDg0
# Draw date is 20231025, step number 74
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDgz
# Draw date is 20231022, step number 75
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDgy
# Draw date is 20231021, step number 76
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDgx
# Draw date is 20231018, step number 77
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDgw
# Draw date is 20231015, step number 78
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDc5
# Draw date is 20231014, step number 79
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDc4
# Draw date is 20231011, step number 80
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDc3
# Draw date is 20231008, step number 81
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDc2
# Draw date is 20231007, step number 82
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDc1
# Draw date is 20231004, step number 83
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDc0
# Draw date is 20231001, step number 84
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDcz
# Draw date is 20230930, step number 85
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDcy
# Draw date is 20230927, step number 86
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDcx
# Draw date is 20230924, step number 87
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDcw
# Draw date is 20230923, step number 88
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDY5
# Draw date is 20230920, step number 89
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDY4
# Draw date is 20230917, step number 90
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDY3
# Draw date is 20230916, step number 91
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDY2
# Draw date is 20230913, step number 92
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDY1
# Draw date is 20230910, step number 93
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDY0
# Draw date is 20230909, step number 94
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDYz
# Draw date is 20230906, step number 95
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDYy
# Draw date is 20230903, step number 96
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDYx
# Draw date is 20230902, step number 97
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDYw
# Draw date is 20230830, step number 98
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDU5
# Draw date is 20230827, step number 99
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDU4
# Draw date is 20230826, step number 100
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDU3
# Draw date is 20230823, step number 101
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDU2
# Draw date is 20230820, step number 102
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDU1
# Draw date is 20230819, step number 103
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDU0
# Draw date is 20230816, step number 104
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDUz
# Draw date is 20230813, step number 105
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDUy
# Draw date is 20230812, step number 106
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDUx
# Draw date is 20230809, step number 107
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDUw
# Draw date is 20230806, step number 108
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDQ5
# Draw date is 20230805, step number 109
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDQ4
# Draw date is 20230802, step number 110
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDQ3
# Draw date is 20230730, step number 111
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDQ2
# Draw date is 20230729, step number 112
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDQ1
# Draw date is 20230726, step number 113
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDQ0
# Draw date is 20230723, step number 114
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDQz
# Draw date is 20230722, step number 115
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDQy
# Draw date is 20230719, step number 116
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDQx
# Draw date is 20230716, step number 117
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDQw
# Draw date is 20230715, step number 118
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDM5
# Draw date is 20230712, step number 119
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDM4
# Draw date is 20230709, step number 120
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDM3
# Draw date is 20230708, step number 121
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDM2
# Draw date is 20230705, step number 122
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDM1
# Draw date is 20230702, step number 123
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDM0
# Draw date is 20230701, step number 124
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDMz
# Draw date is 20230628, step number 125
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDMy
# Draw date is 20230625, step number 126
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDMx
# Draw date is 20230624, step number 127
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDMw
# Draw date is 20230621, step number 128
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDI5
# Draw date is 20230618, step number 129
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDI4
# Draw date is 20230617, step number 130
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDI3
# Draw date is 20230614, step number 131
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDI2
# Draw date is 20230611, step number 132
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDI1
# Draw date is 20230610, step number 133
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDI0
# Draw date is 20230607, step number 134
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDIz
# Draw date is 20230604, step number 135
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDIy
# Draw date is 20230603, step number 136
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDIx
# Draw date is 20230531, step number 137
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDIw
# Draw date is 20230528, step number 138
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDE5
# Draw date is 20230527, step number 139
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDE4
# Draw date is 20230524, step number 140
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDE3
# Draw date is 20230521, step number 141
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDE2
# Draw date is 20230520, step number 142
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDE1
# Draw date is 20230517, step number 143
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDE0
# Draw date is 20230514, step number 144
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDEz
# Draw date is 20230513, step number 145
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDEy
# Draw date is 20230510, step number 146
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDEx
# Draw date is 20230507, step number 147
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDEw
# Draw date is 20230506, step number 148
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDA5
# Draw date is 20230503, step number 149
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDA4
# Draw date is 20230430, step number 150
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDA3
# Draw date is 20230429, step number 151
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDA2
# Draw date is 20230426, step number 152
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDA1
# Draw date is 20230423, step number 153
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDA0
# Draw date is 20230422, step number 154
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDAz
# Draw date is 20230419, step number 155
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDAy
# Draw date is 20230416, step number 156
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDAx
# Draw date is 20230415, step number 157
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj01MDAw
# Draw date is 20230412, step number 158
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTk5
# Draw date is 20230409, step number 159
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTk4
# Draw date is 20230408, step number 160
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTk3
# Draw date is 20230405, step number 161
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTk2
# Draw date is 20230402, step number 162
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTk1
# Draw date is 20230401, step number 163
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTk0
# Draw date is 20230329, step number 164
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTkz
# Draw date is 20230326, step number 165
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTky
# Draw date is 20230325, step number 166
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTkx
# Draw date is 20230322, step number 167
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTkw
# Draw date is 20230319, step number 168
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTg5
# Draw date is 20230318, step number 169
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTg4
# Draw date is 20230315, step number 170
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTg3
# Draw date is 20230312, step number 171
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTg2
# Draw date is 20230311, step number 172
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTg1
# Draw date is 20230308, step number 173
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTg0
# Draw date is 20230305, step number 174
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTgz
# Draw date is 20230304, step number 175
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTgy
# Draw date is 20230301, step number 176
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTgx
# Draw date is 20230226, step number 177
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTgw
# Draw date is 20230225, step number 178
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTc5
# Draw date is 20230222, step number 179
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTc4
# Draw date is 20230219, step number 180
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTc3
# Draw date is 20230218, step number 181
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTc2
# Draw date is 20230215, step number 182
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTc1
# Draw date is 20230212, step number 183
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTc0
# Draw date is 20230211, step number 184
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTcz
# Draw date is 20230208, step number 185
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTcy
# Draw date is 20230205, step number 186
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTcx
# Draw date is 20230204, step number 187
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTcw
# Draw date is 20230201, step number 188
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTY5
# Draw date is 20230129, step number 189
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTY4
# Draw date is 20230128, step number 190
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTY3
# Draw date is 20230125, step number 191
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTY2
# Draw date is 20230122, step number 192
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTY1
# Draw date is 20230121, step number 193
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTY0
# Draw date is 20230118, step number 194
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTYz
# Draw date is 20230115, step number 195
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTYy
# Draw date is 20230114, step number 196
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTYx
# Draw date is 20230111, step number 197
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTYw
# Draw date is 20230108, step number 198
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTU5
# Draw date is 20230107, step number 199
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTU4
# Draw date is 20230104, step number 200
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTU3
# Draw date is 20230101, step number 201
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTU2
# Draw date is 20221231, step number 202
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTU1
# Draw date is 20221228, step number 203
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTU0
# Draw date is 20221225, step number 204
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTUz
# Draw date is 20221224, step number 205
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTUy
# Draw date is 20221221, step number 206
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTUx
# Draw date is 20221218, step number 207
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTUw
# Draw date is 20221217, step number 208
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTQ5
# Draw date is 20221214, step number 209
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTQ4
# Draw date is 20221211, step number 210
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTQ3
# Draw date is 20221210, step number 211
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTQ2
# Draw date is 20221207, step number 212
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTQ1
# Draw date is 20221204, step number 213
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTQ0
# Draw date is 20221203, step number 214
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTQz
# Draw date is 20221130, step number 215
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTQy
# Draw date is 20221127, step number 216
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTQx
# Draw date is 20221126, step number 217
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTQw
# Draw date is 20221123, step number 218
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTM5
# Draw date is 20221120, step number 219
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTM4
# Draw date is 20221119, step number 220
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTM3
# Draw date is 20221116, step number 221
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTM2
# Draw date is 20221113, step number 222
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTM1
# Draw date is 20221112, step number 223
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTM0
# Draw date is 20221109, step number 224
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTMz
# Draw date is 20221106, step number 225
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTMy
# Draw date is 20221105, step number 226
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTMx
# Draw date is 20221102, step number 227
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTMw
# Draw date is 20221030, step number 228
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTI5
# Draw date is 20221029, step number 229
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTI4
# Draw date is 20221026, step number 230
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTI3
# Draw date is 20221023, step number 231
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTI2
# Draw date is 20221022, step number 232
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTI1
# Draw date is 20221019, step number 233
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTI0
# Draw date is 20221016, step number 234
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTIz
# Draw date is 20221015, step number 235
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTIy
# Draw date is 20221012, step number 236
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTIx
# Draw date is 20221009, step number 237
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTIw
# Draw date is 20221008, step number 238
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTE5
# Draw date is 20221005, step number 239
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTE4
# Draw date is 20221002, step number 240
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTE3
# Draw date is 20221001, step number 241
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTE2
# Draw date is 20220928, step number 242
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTE1
# Draw date is 20220925, step number 243
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTE0
# Draw date is 20220924, step number 244
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTEz
# Draw date is 20220921, step number 245
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTEy
# Draw date is 20220918, step number 246
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTEx
# Draw date is 20220917, step number 247
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTEw
# Draw date is 20220914, step number 248
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTA5
# Draw date is 20220911, step number 249
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTA4
# Draw date is 20220910, step number 250
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTA3
# Draw date is 20220907, step number 251
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTA2
# Draw date is 20220904, step number 252
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTA1
# Draw date is 20220903, step number 253
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTA0
# Draw date is 20220831, step number 254
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTAz
# Draw date is 20220828, step number 255
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTAy
# Draw date is 20220827, step number 256
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTAx
# Draw date is 20220824, step number 257
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00OTAw
# Draw date is 20220821, step number 258
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODk5
# Draw date is 20220820, step number 259
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODk4
# Draw date is 20220817, step number 260
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODk3
# Draw date is 20220814, step number 261
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODk2
# Draw date is 20220813, step number 262
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODk1
# Draw date is 20220810, step number 263
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODk0
# Draw date is 20220807, step number 264
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODkz
# Draw date is 20220806, step number 265
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODky
# Draw date is 20220803, step number 266
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODkx
# Draw date is 20220731, step number 267
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODkw
# Draw date is 20220730, step number 268
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODg5
# Draw date is 20220727, step number 269
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODg4
# Draw date is 20220724, step number 270
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODg3
# Draw date is 20220723, step number 271
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODg2
# Draw date is 20220720, step number 272
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODg1
# Draw date is 20220717, step number 273
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODg0
# Draw date is 20220716, step number 274
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODgz
# Draw date is 20220713, step number 275
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODgy
# Draw date is 20220710, step number 276
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODgx
# Draw date is 20220709, step number 277
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODgw
# Draw date is 20220706, step number 278
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODc5
# Draw date is 20220703, step number 279
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODc4
# Draw date is 20220702, step number 280
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODc3
# Draw date is 20220629, step number 281
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODc2
# Draw date is 20220626, step number 282
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODc1
# Draw date is 20220625, step number 283
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODc0
# Draw date is 20220622, step number 284
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODcz
# Draw date is 20220619, step number 285
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODcy
# Draw date is 20220618, step number 286
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODcx
# Draw date is 20220615, step number 287
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODcw
# Draw date is 20220612, step number 288
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODY5
# Draw date is 20220611, step number 289
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODY4
# Draw date is 20220608, step number 290
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODY3
# Draw date is 20220605, step number 291
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODY2
# Draw date is 20220604, step number 292
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODY1
# Draw date is 20220601, step number 293
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODY0
# Draw date is 20220529, step number 294
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODYz
# Draw date is 20220528, step number 295
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODYy
# Draw date is 20220525, step number 296
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODYx
# Draw date is 20220522, step number 297
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODYw
# Draw date is 20220521, step number 298
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODU5
# Draw date is 20220518, step number 299
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODU4
# Draw date is 20220515, step number 300
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODU3
# Draw date is 20220514, step number 301
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODU2
# Draw date is 20220511, step number 302
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODU1
# Draw date is 20220508, step number 303
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODU0
# Draw date is 20220507, step number 304
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODUz
# Draw date is 20220504, step number 305
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODUy
# Draw date is 20220501, step number 306
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODUx
# Draw date is 20220430, step number 307
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODUw
# Draw date is 20220427, step number 308
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODQ5
# Draw date is 20220424, step number 309
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODQ4
# Draw date is 20220423, step number 310
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODQ3
# Draw date is 20220420, step number 311
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODQ2
# Draw date is 20220417, step number 312
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODQ1
# Draw date is 20220416, step number 313
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODQ0
# Draw date is 20220413, step number 314
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODQz
# Draw date is 20220410, step number 315
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODQy
# Draw date is 20220409, step number 316
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODQx
# Draw date is 20220406, step number 317
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODQw
# Draw date is 20220403, step number 318
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODM5
# Draw date is 20220402, step number 319
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODM4
# Draw date is 20220330, step number 320
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODM3
# Draw date is 20220327, step number 321
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODM2
# Draw date is 20220326, step number 322
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODM1
# Draw date is 20220323, step number 323
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODM0
# Draw date is 20220320, step number 324
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODMz
# Draw date is 20220319, step number 325
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODMy
# Draw date is 20220316, step number 326
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODMx
# Draw date is 20220313, step number 327
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODMw
# Draw date is 20220312, step number 328
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODI5
# Draw date is 20220309, step number 329
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODI4
# Draw date is 20220306, step number 330
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODI3
# Draw date is 20220305, step number 331
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODI2
# Draw date is 20220302, step number 332
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODI1
# Draw date is 20220227, step number 333
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODI0
# ...
# Draw date is 20220109, step number 354
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODAz
# Draw date is 20220108, step number 355
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODAy
# Draw date is 20220105, step number 356
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODAx
# Draw date is 20220102, step number 357
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00ODAw
# Draw date is 20220101, step number 358
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzk5
# Draw date is 20211229, step number 359
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzk4
# Draw date is 20211226, step number 360
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzk3
# Draw date is 20211225, step number 361
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzk2
# Draw date is 20211222, step number 362
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzk1
# Draw date is 20211219, step number 363
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzk0
# Draw date is 20211218, step number 364
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzkz
# Draw date is 20211215, step number 365
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzky
# Draw date is 20211212, step number 366
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzkx
# Draw date is 20211211, step number 367
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzkw
# Draw date is 20211208, step number 368
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzg5
# Draw date is 20211205, step number 369
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzg4
# Draw date is 20211204, step number 370
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzg3
# Draw date is 20211201, step number 371
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzg2
# Draw date is 20211128, step number 372
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzg1
# Draw date is 20211127, step number 373
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzg0
# Draw date is 20211124, step number 374
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzgz
# Draw date is 20211121, step number 375
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzgy
# Draw date is 20211120, step number 376
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzgx
# Draw date is 20211117, step number 377
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzgw
# Draw date is 20211114, step number 378
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzc5
# Draw date is 20211113, step number 379
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzc4
# Draw date is 20211110, step number 380
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzc3
# Draw date is 20211107, step number 381
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzc2
# Draw date is 20211106, step number 382
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzc1
# Draw date is 20211103, step number 383
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzc0
# Draw date is 20211031, step number 384
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzcz
# Draw date is 20211030, step number 385
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzcy
# Draw date is 20211027, step number 386
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzcx
# Draw date is 20211024, step number 387
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Nzcw
# Draw date is 20211023, step number 388
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzY5
# Draw date is 20211020, step number 389
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzY4
# Draw date is 20211017, step number 390
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzY3
# Draw date is 20211016, step number 391
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzY2
# Draw date is 20211013, step number 392
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzY1
# Draw date is 20211010, step number 393
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzY0
# Draw date is 20211009, step number 394
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzYz
# Draw date is 20211006, step number 395
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzYy
# Draw date is 20211003, step number 396
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzYx
# Draw date is 20211002, step number 397
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzYw
# Draw date is 20210929, step number 398
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzU5
# Draw date is 20210926, step number 399
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzU4
# Draw date is 20210925, step number 400
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzU3
# Draw date is 20210922, step number 401
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzU2
# Draw date is 20210919, step number 402
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzU1
# Draw date is 20210918, step number 403
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzU0
# Draw date is 20210915, step number 404
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzUz
# Draw date is 20210912, step number 405
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzUy
# Draw date is 20210911, step number 406
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzUx
# Draw date is 20210908, step number 407
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzUw
# Draw date is 20210905, step number 408
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzQ5
# Draw date is 20210904, step number 409
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzQ4
# Draw date is 20210901, step number 410
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzQ3
# Draw date is 20210829, step number 411
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzQ2
# Draw date is 20210828, step number 412
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzQ1
# Draw date is 20210825, step number 413
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzQ0
# Draw date is 20210822, step number 414
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzQz
# Draw date is 20210821, step number 415
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzQy
# Draw date is 20210818, step number 416
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzQx
# Draw date is 20210815, step number 417
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzQw
# Draw date is 20210814, step number 418
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzM5
# Draw date is 20210811, step number 419
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzM4
# Draw date is 20210808, step number 420
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzM3
# Draw date is 20210807, step number 421
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzM2
# Draw date is 20210804, step number 422
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzM1
# Draw date is 20210801, step number 423
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzM0
# Draw date is 20210731, step number 424
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzMz
# Draw date is 20210728, step number 425
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzMy
# Draw date is 20210725, step number 426
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzMx
# Draw date is 20210724, step number 427
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzMw
# Draw date is 20210721, step number 428
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzI5
# Draw date is 20210718, step number 429
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzI4
# Draw date is 20210717, step number 430
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzI3
# Draw date is 20210714, step number 431
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzI2
# Draw date is 20210711, step number 432
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzI1
# Draw date is 20210710, step number 433
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzI0
# Draw date is 20210707, step number 434
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzIz
# Draw date is 20210704, step number 435
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzIy
# Draw date is 20210703, step number 436
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzIx
# Draw date is 20210630, step number 437
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzIw
# Draw date is 20210627, step number 438
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzE5
# Draw date is 20210626, step number 439
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzE4
# Draw date is 20210623, step number 440
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzE3
# Draw date is 20210620, step number 441
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzE2
# Draw date is 20210619, step number 442
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzE1
# Draw date is 20210616, step number 443
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzE0
# Draw date is 20210613, step number 444
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzEz
# Draw date is 20210612, step number 445
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzEy
# Draw date is 20210609, step number 446
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzEx
# Draw date is 20210606, step number 447
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzEw
# Draw date is 20210605, step number 448
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzA5
# Draw date is 20210602, step number 449
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzA4
# Draw date is 20210530, step number 450
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzA3
# Draw date is 20210529, step number 451
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzA2
# Draw date is 20210526, step number 452
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzA1
# Draw date is 20210523, step number 453
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzA0
# Draw date is 20210522, step number 454
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzAz
# Draw date is 20210519, step number 455
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzAy
# Draw date is 20210516, step number 456
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzAx
# Draw date is 20210515, step number 457
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00NzAw
# Draw date is 20210512, step number 458
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Njk5
# Draw date is 20210509, step number 459
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Njk4
# Draw date is 20210508, step number 460
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Njk3
# Draw date is 20210505, step number 461
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Njk2
# Draw date is 20210502, step number 462
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Njk1
# Draw date is 20210501, step number 463
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Njk0
# Draw date is 20210428, step number 464
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Njkz
# Draw date is 20210425, step number 465
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Njky
# Draw date is 20210424, step number 466
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Njkx
# Draw date is 20210421, step number 467
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Njkw
# Draw date is 20210418, step number 468
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Njg5
# Draw date is 20210417, step number 469
# https://www.singaporepools.com.sg/en/product/Pages/4d_results.aspx?sppl=RHJhd051bWJlcj00Njg4
# final dataframe is...
#        DrawDate          PrizeType PrizeNumber
# 0      20240414        First_Prize        9406
# 1      20240414       Second_Prize        4726
# 2      20240414        Third_Prize        1892
# 3      20240414      Starter_Prize        0175
# 4      20240414      Starter_Prize        2321
# ...         ...                ...         ...
# 10805  20210417  Consolation_Prize        4903
# 10806  20210417  Consolation_Prize        5521
# 10807  20210417  Consolation_Prize        7078
# 10808  20210417  Consolation_Prize        7614
# 10809  20210417  Consolation_Prize        9236
#
# [10810 rows x 3 columns]

# %%
#Determine ibet combinations. ie, position of the numbers does not matter. if 1234 is drawn, 2134, 3124 etc will win as well.
#instead of doing individual number search, a sorting of the PrizeNumber can be done and groupby thereafter.
def sort_digits(number_str):
    return ''.join(sorted(number_str))

full_data['ibet'] = full_data['PrizeNumber'].apply(sort_digits)
full_data.head(5)
# Out:
#    DrawDate      PrizeType PrizeNumber  ibet        digits
# 0  20240414    First_Prize        9406  0469  [9, 4, 0, 6]
# 1  20240414   Second_Prize        4726  2467  [4, 7, 2, 6]
# 2  20240414    Third_Prize        1892  1289  [1, 8, 9, 2]
# 3  20240414  Starter_Prize        0175  0157  [0, 1, 7, 5]
# 4  20240414  Starter_Prize        2321  1223  [2, 3, 2, 1]

# %%
#write to csv file
full_data.to_csv('full_data.csv',index=False)

# %%
#explode based on digits of each draw
#list of lists
draw_digits_all = full_data
draw_digits_all['digits'] = draw_digits_all['PrizeNumber'].apply(list) #break up string into individual characters in a list
draw_digits_all_explode = draw_digits_all.explode('digits')
draw_digits_all_explode.head(5)

#group by drawdate, digits
#digit_count = draw_digits_all_explode.groupby(['DrawDate','digits'],as_index=False)['PrizeNumber'].count().rename(columns={'PrizeNumber':'count'})
digit_count = draw_digits_all_explode.groupby(['DrawDate','digits']).size().reset_index(name='count')
digit_count.head(11)

#write to csv file
digit_count.to_csv('digit_count.csv',index=False)

# %%
#full number combinations
all_iterations = [f"{i:04d}" for i in range(10000)]
all_iterations_df = pd.DataFrame(all_iterations, columns = ['number'])

#drawn number counts
lucky_numbers_group = full_data.groupby(['PrizeNumber']).size().reset_index(name='count')
lucky_numbers_group.head(5)
#numbers which have not appeared at all - unlucky numbers
unlucky_numbers = all_iterations_df.merge(lucky_numbers_group,how='left',left_on='number',right_on='PrizeNumber')
unlucky_numbers = unlucky_numbers[unlucky_numbers['PrizeNumber'].isna()]['number']
unlucky_numbers.size
# Out:
# 3385

# %% [markdown]
# ## Analysis
# ### Lucky and unlucky numbers
#
# Interestingly, over the period 3 years, there are some combination of numbers that have appeared more frequently than others.
# |Numbers | Drawn Occurrence |
# |--------|-|
# |0170, 0627, 3192, 5943, 6977 (5 numbers)| 6 |
# | 41 numbers | 5 |
#
# If we continue with our assumption that it is a fair equal chance game, the only explaination is that these are lucky numbers. Inversely there are also unlucky numbers. These are number combinations that have never occurred before in the past 3 years. There are a total of 3,385 unlucky numbers between the 3 year period and this represents **33.85%** of all possible number combinations.

# %%
#total number of permutations of 4d number is 10*10*10*10. 0-9 number
all_possible = 10*10*10*10
print(all_possible)
# Out:
# 10000

# %%
percentage_drawn = round((len(full_data ['PrizeNumber'].unique())/all_possible) *100,2)
percentage_drawn
# Out:
# 66.15

# %% [markdown]
# # Machine learning
# To identify patterns
